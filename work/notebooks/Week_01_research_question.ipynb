# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ### Refresh / Content Opportunity Scoring
#
# I selected the Refresh / Content Opportunity Scoring lane because websites often contain hundreds or thousands of pages, making it difficult to manually decide which pages should be updated first. This project aims to identify pages that may benefit from a content refresh based on their SEO performance metrics. A data-driven scoring approach can help prioritize review efforts and support more efficient content management.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ###  The question:
# Which webpages should be refreshed first?
#
# ### Decision:
# This project helps the SEO and content team decide which webpages should be prioritized for content updates instead of reviewing every page manually.
#
# ### Action:
# SEO managers or content editors acts and they will review and update the pages that receive the highest refresh opportunity scores.
#
# ### Cost of a wrong call
# If the system recommends refreshing the wrong pages, the team may spend time improving pages with little potential while overlooking pages that could generate more traffic. This can lead to inefficient use of time and missed opportunities for growth.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
elif os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")

import pandas as pd, numpy as np
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

df["is_declining_label"] = (
    df["trend_direction"].str.lower().eq("down").astype(int)
)

# --- Supporting numbers ---
num_pages = len(df)
declining_rate = df["is_declining_label"].mean() * 100
avg_ctr = df["ctr"].mean()

print(f"Total pages: {num_pages:,}")
print(f"Pages with declining trend: {declining_rate:.1f}%")
print(f"Average CTR: {avg_ctr:.2f}%")
# Out:
# Total pages: 30,000
# Pages with declining trend: 54.2%
# Average CTR: 0.51%

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ### What you can claim
# This project provides decision-support by identifying pages that appear to have higher content refresh opportunities based on observed and measured SEO performance metrics. The results indicate directional patterns that can help prioritize which pages should be reviewed first, rather than making definitive decisions.
#
# ### What you cannot claim
# This project does not provide causal proof that refreshing a page will improve its Google rankings or traffic. It cannot predict Google's ranking algorithm or guarantee future performance. The findings are based only on observed and measured historical data and should be interpreted as directional evidence for decision-support, not as certain outcomes.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
